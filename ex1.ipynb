# %%
import transformers

print(transformers.__version__)
print(transformers.__file__)
# Out:
# 5.12.1
# C:\Users\Janani\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\__init__.py
